# %%
print("Hello EduPredict!")
# Out:
# Hello EduPredict!

# %%
import pandas as pd
import numpy as np

print("EduPredict - Student Dropout Prediction")
print("Environment ready!")
# Out:
# EduPredict - Student Dropout Prediction
# Environment ready!

# %%
import os

data_path = "../data"

print(os.listdir(data_path))
# Out:
# ['data.csv']

# %%
df = pd.read_csv("../data/data.csv")

df.head()
# Out:
#   Marital status;Application mode;Application order;Course;"Daytime/evening attendance\t";Previous qualification;Previous qualification (grade);Nacionality;Mother's qualification;Father's qualification;Mother's occupation;Father's occupation;Admission grade;Displaced;Educational special needs;Debtor;Tuition fees up to date;Gender;Scholarship holder;Age at enrollment;International;Curricular units 1st sem (credited);Curricular units 1st sem (enrolled);Curricular units 1st sem (evaluations);Curricular units 1st sem (approved);Curricular units 1st sem (grade);Curricular units 1st sem (without evaluations);Curricular units 2nd sem (credited);Curricular units 2nd sem (enrolled);Curricular units 2nd sem (evaluations);Curricular units 2nd sem (approved);Curricular units 2nd sem (grade);Curricular units 2nd sem (without evaluations);Unemployment rate;Inflation rate;GDP;Target
# 0  1;17;5;171;1;1;122.0;1;19;12;5;9;127.3;1;0;0;1...
# 1  1;15;1;9254;1;1;160.0;1;1;3;3;3;142.5;1;0;0;0;...
# ...

# %%
df = pd.read_csv("../data/data.csv", sep=";")

df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
print("Number of students:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of students: 4424
# Number of columns: 37

# %%
df.shape
# Out:
# (4424, 37)

# %%
df.columns.tolist()
# Out:
# ['Marital status',
#  'Application mode',
#  'Application order',
#  'Course',
#  'Daytime/evening attendance\t',
#  'Previous qualification',
#  'Previous qualification (grade)',
#  'Nacionality',
#  "Mother's qualification",
#  "Father's qualification",
#  "Mother's occupation",
#  "Father's occupation",
#  'Admission grade',
#  'Displaced',
#  'Educational special needs',
#  'Debtor',
#  'Tuition fees up to date',
#  'Gender',
#  'Scholarship holder',
#  'Age at enrollment',
#  'International',
#  'Curricular units 1st sem (credited)',
#  'Curricular units 1st sem (enrolled)',
#  'Curricular units 1st sem (evaluations)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 1st sem (without evaluations)',
#  'Curricular units 2nd sem (credited)',
#  'Curricular units 2nd sem (enrolled)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (approved)',
#  'Curricular units 2nd sem (grade)',
# ...

# %%
df["Target"].value_counts()
# Out:
# Target
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: count, dtype: int64

# %%
df["Target"].value_counts(normalize=True) * 100
# Out:
# Target
# Graduate    49.932188
# Dropout     32.120253
# Enrolled    17.947559
# Name: proportion, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance	                     4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance\t                      0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# ...

# %%
print("Number of students:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of students: 4424
# Number of columns: 37

# %%
df.columns.tolist()
# Out:
# ['Marital status',
#  'Application mode',
#  'Application order',
#  'Course',
#  'Daytime/evening attendance\t',
#  'Previous qualification',
#  'Previous qualification (grade)',
#  'Nacionality',
#  "Mother's qualification",
#  "Father's qualification",
#  "Mother's occupation",
#  "Father's occupation",
#  'Admission grade',
#  'Displaced',
#  'Educational special needs',
#  'Debtor',
#  'Tuition fees up to date',
#  'Gender',
#  'Scholarship holder',
#  'Age at enrollment',
#  'International',
#  'Curricular units 1st sem (credited)',
#  'Curricular units 1st sem (enrolled)',
#  'Curricular units 1st sem (evaluations)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 1st sem (without evaluations)',
#  'Curricular units 2nd sem (credited)',
#  'Curricular units 2nd sem (enrolled)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (approved)',
#  'Curricular units 2nd sem (grade)',
# ...

# %%
df["Target"].value_counts()
# Out:
# Target
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance\t                      0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))

sns.countplot(data=df, x="Target")

plt.title("Student Outcome Distribution")
plt.xlabel("Student Outcome")
plt.ylabel("Number of Students")

plt.show()

# %%
target_counts = df["Target"].value_counts()

plt.figure(figsize=(7, 7))

plt.pie(
    target_counts,
    labels=target_counts.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Student Outcome Percentage")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.histplot(
    data=df,
    x="Age at enrollment",
    bins=20,
    kde=True
)

plt.title("Age Distribution of Students")
plt.xlabel("Age at Enrollment")
plt.ylabel("Number of Students")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="Target",
    y="Age at enrollment"
)

plt.title("Age at Enrollment vs Student Outcome")
plt.xlabel("Student Outcome")
plt.ylabel("Age at Enrollment")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="Target",
    y="Admission grade"
)

plt.title("Admission Grade vs Student Outcome")
plt.xlabel("Student Outcome")
plt.ylabel("Admission Grade")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="Target",
    y="Curricular units 1st sem (approved)"
)

plt.title("First Semester Approved Units vs Student Outcome")
plt.xlabel("Student Outcome")
plt.ylabel("Approved Units")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="Target",
    y="Curricular units 1st sem (grade)"
)

plt.title("First Semester Grade vs Student Outcome")
plt.xlabel("Student Outcome")
plt.ylabel("First Semester Grade")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="Target",
    y="Curricular units 2nd sem (grade)"
)

plt.title("Second Semester Grade vs Student Outcome")
plt.xlabel("Student Outcome")
plt.ylabel("Second Semester Grade")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="Target",
    y="Curricular units 1st sem (approved)"
)

plt.title("First Semester Approved Units vs Student Outcome")
plt.xlabel("Student Outcome")
plt.ylabel("Approved Units")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="Target",
    y="Curricular units 2nd sem (approved)"
)

plt.title("Second Semester Approved Units vs Student Outcome")
plt.xlabel("Student Outcome")
plt.ylabel("Approved Units")

plt.show()

# %%
target_numeric = df["Target"].map({
    "Dropout": 0,
    "Enrolled": 1,
    "Graduate": 2
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 target_numeric = df["Target"].map({
#       2     "Dropout": 0,
#       3     "Enrolled": 1,
#       4     "Graduate": 2
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries loaded successfully")
# Out:
# Libraries loaded successfully

# %%
df = pd.read_csv("../data/data.csv", sep=";")

print("Dataset loaded successfully")
print("Shape:", df.shape)
# Out:
# Dataset loaded successfully
# Shape: (4424, 37)

# %%
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
target_numeric = df["Target"].map({
    "Dropout": 0,
    "Enrolled": 1,
    "Graduate": 2
})

# %%
target_numeric.head()
# Out:
# 0    0
# 1    2
# 2    0
# 3    2
# 4    2
# Name: Target, dtype: int64

# %%
target_numeric.value_counts()
# Out:
# Target
# 2    2209
# 0    1421
# 1     794
# Name: count, dtype: int64

# %%
numeric_df = df.select_dtypes(include="number").copy()

numeric_df["Target_numeric"] = target_numeric

# %%
correlation = numeric_df.corr()

# %%
plt.figure(figsize=(16, 12))

sns.heatmap(
    correlation,
    cmap="coolwarm",
    center=0
)

plt.title("Correlation Heatmap")

plt.show()
# Out:
# D:\Sunny Project\EduPredict\.venv\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# D:\Sunny Project\EduPredict\.venv\Lib\site-packages\IPython\core\pylabtools.py:158: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
target_corr = correlation["Target_numeric"].drop("Target_numeric")

target_corr = target_corr.abs().sort_values(ascending=False)

target_corr.head(10)
# Out:
# Curricular units 2nd sem (approved)    0.624157
# Curricular units 2nd sem (grade)       0.566827
# Curricular units 1st sem (approved)    0.529123
# Curricular units 1st sem (grade)       0.485207
# Tuition fees up to date                0.409827
# Scholarship holder                     0.297595
# Age at enrollment                      0.243438
# Debtor                                 0.240999
# Gender                                 0.229270
# Application mode                       0.221747
# Name: Target_numeric, dtype: float64

# %%
target_corr.head(10)
# Out:
# Curricular units 2nd sem (approved)    0.624157
# Curricular units 2nd sem (grade)       0.566827
# Curricular units 1st sem (approved)    0.529123
# Curricular units 1st sem (grade)       0.485207
# Tuition fees up to date                0.409827
# Scholarship holder                     0.297595
# Age at enrollment                      0.243438
# Debtor                                 0.240999
# Gender                                 0.229270
# Application mode                       0.221747
# Name: Target_numeric, dtype: float64

# %%
df.columns.tolist()
# Out:
# ['Marital status',
#  'Application mode',
#  'Application order',
#  'Course',
#  'Daytime/evening attendance\t',
#  'Previous qualification',
#  'Previous qualification (grade)',
#  'Nacionality',
#  "Mother's qualification",
#  "Father's qualification",
#  "Mother's occupation",
#  "Father's occupation",
#  'Admission grade',
#  'Displaced',
#  'Educational special needs',
#  'Debtor',
#  'Tuition fees up to date',
#  'Gender',
#  'Scholarship holder',
#  'Age at enrollment',
#  'International',
#  'Curricular units 1st sem (credited)',
#  'Curricular units 1st sem (enrolled)',
#  'Curricular units 1st sem (evaluations)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 1st sem (without evaluations)',
#  'Curricular units 2nd sem (credited)',
#  'Curricular units 2nd sem (enrolled)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (approved)',
#  'Curricular units 2nd sem (grade)',
# ...

# %%
df.columns = df.columns.str.strip()

# %%
df.columns.tolist()
# Out:
# ['Marital status',
#  'Application mode',
#  'Application order',
#  'Course',
#  'Daytime/evening attendance',
#  'Previous qualification',
#  'Previous qualification (grade)',
#  'Nacionality',
#  "Mother's qualification",
#  "Father's qualification",
#  "Mother's occupation",
#  "Father's occupation",
#  'Admission grade',
#  'Displaced',
#  'Educational special needs',
#  'Debtor',
#  'Tuition fees up to date',
#  'Gender',
#  'Scholarship holder',
#  'Age at enrollment',
#  'International',
#  'Curricular units 1st sem (credited)',
#  'Curricular units 1st sem (enrolled)',
#  'Curricular units 1st sem (evaluations)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 1st sem (without evaluations)',
#  'Curricular units 2nd sem (credited)',
#  'Curricular units 2nd sem (enrolled)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (approved)',
#  'Curricular units 2nd sem (grade)',
# ...

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
df.dtypes
# Out:
# Marital status                                      int64
# Application mode                                    int64
# Application order                                   int64
# Course                                              int64
# Daytime/evening attendance                          int64
# Previous qualification                              int64
# Previous qualification (grade)                    float64
# Nacionality                                         int64
# Mother's qualification                              int64
# Father's qualification                              int64
# Mother's occupation                                 int64
# Father's occupation                                 int64
# Admission grade                                   float64
# Displaced                                           int64
# Educational special needs                           int64
# Debtor                                              int64
# ...

# %%
df["Target"].unique()
# Out:
# <ArrowStringArray>
# ['Dropout', 'Graduate', 'Enrolled']
# Length: 3, dtype: str

# %%
df["Target"].value_counts()
# Out:
# Target
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: count, dtype: int64

# %%
X = df.drop("Target", axis=1)
y = df["Target"]

# %%
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (4424, 36)
# y shape: (4424,)

# %%
df.columns = df.columns.str.strip()

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
df.dtypes
# Out:
# Marital status                                      int64
# Application mode                                    int64
# Application order                                   int64
# Course                                              int64
# Daytime/evening attendance                          int64
# Previous qualification                              int64
# Previous qualification (grade)                    float64
# Nacionality                                         int64
# Mother's qualification                              int64
# Father's qualification                              int64
# Mother's occupation                                 int64
# Father's occupation                                 int64
# Admission grade                                   float64
# Displaced                                           int64
# Educational special needs                           int64
# Debtor                                              int64
# ...

# %%
print(df["Target"].unique())
print(df["Target"].value_counts())
# Out:
# <ArrowStringArray>
# ['Dropout', 'Graduate', 'Enrolled']
# Length: 3, dtype: str
# Target
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: count, dtype: int64

# %%
X = df.drop("Target", axis=1)
y = df["Target"]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (4424, 36)
# y shape: (4424,)

# %%
X.dtypes
# Out:
# Marital status                                      int64
# Application mode                                    int64
# Application order                                   int64
# Course                                              int64
# Daytime/evening attendance                          int64
# Previous qualification                              int64
# Previous qualification (grade)                    float64
# Nacionality                                         int64
# Mother's qualification                              int64
# Father's qualification                              int64
# Mother's occupation                                 int64
# Father's occupation                                 int64
# Admission grade                                   float64
# Displaced                                           int64
# Educational special needs                           int64
# Debtor                                              int64
# ...

# %%
for column in X.columns:
    print(f"{column}: {X[column].nunique()} unique values")
# Out:
# Marital status: 6 unique values
# Application mode: 18 unique values
# Application order: 8 unique values
# Course: 17 unique values
# Daytime/evening attendance: 2 unique values
# Previous qualification: 17 unique values
# Previous qualification (grade): 101 unique values
# Nacionality: 21 unique values
# Mother's qualification: 29 unique values
# Father's qualification: 34 unique values
# Mother's occupation: 32 unique values
# Father's occupation: 46 unique values
# Admission grade: 620 unique values
# Displaced: 2 unique values
# Educational special needs: 2 unique values
# Debtor: 2 unique values
# Tuition fees up to date: 2 unique values
# Gender: 2 unique values
# Scholarship holder: 2 unique values
# Age at enrollment: 46 unique values
# International: 2 unique values
# Curricular units 1st sem (credited): 21 unique values
# Curricular units 1st sem (enrolled): 23 unique values
# Curricular units 1st sem (evaluations): 35 unique values
# ...

# %%
nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 nunique()
#
# NameError: name 'nunique' is not defined

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
# Out:
# X_train: (3539, 36)
# X_test : (885, 36)
# y_train: (3539,)
# y_test : (885,)

# %%
print("Training distribution:")
print(y_train.value_counts())

print("\nTesting distribution:")
print(y_test.value_counts())
# Out:
# Training distribution:
# Target
# Graduate    1767
# Dropout     1137
# Enrolled     635
# Name: count, dtype: int64
#
# Testing distribution:
# Target
# Graduate    442
# Dropout     284
# Enrolled    159
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)

print("\nTraining distribution:")
print(y_train.value_counts())

print("\nTesting distribution:")
print(y_test.value_counts())
# Out:
# X_train: (3539, 36)
# X_test : (885, 36)
# y_train: (3539,)
# y_test : (885,)
#
# Training distribution:
# Target
# Graduate    1767
# Dropout     1137
# Enrolled     635
# Name: count, dtype: int64
#
# Testing distribution:
# Target
# Graduate    442
# Dropout     284
# Enrolled    159
# Name: count, dtype: int64

# %%
categorical_features = [
    "Marital status",
    "Application mode",
    "Application order",
    "Course",
    "Daytime/evening attendance",
    "Previous qualification",
    "Nacionality",
    "Mother's qualification",
    "Father's qualification",
    "Mother's occupation",
    "Father's occupation"
]

# %%
numerical_features = [
    "Previous qualification (grade)",
    "Admission grade",
    "Age at enrollment",
    "Curricular units 1st sem (credited)",
    "Curricular units 1st sem (enrolled)",
    "Curricular units 1st sem (evaluations)",
    "Curricular units 1st sem (approved)",
    "Curricular units 1st sem (grade)",
    "Curricular units 1st sem (without evaluations)",
    "Curricular units 2nd sem (credited)",
    "Curricular units 2nd sem (enrolled)",
    "Curricular units 2nd sem (evaluations)",
    "Curricular units 2nd sem (approved)",
    "Curricular units 2nd sem (grade)",
    "Curricular units 2nd sem (without evaluations)",
    "Unemployment rate",
    "Inflation rate",
    "GDP"
]

# %%
binary_features = [
    "Displaced",
    "Educational special needs",
    "Debtor",
    "Tuition fees up to date",
    "Gender",
    "Scholarship holder",
    "International"
]

# %%
all_features = categorical_features + numerical_features + binary_features

print("Total features defined:", len(all_features))
print("Actual features:", X.shape[1])

missing_features = set(X.columns) - set(all_features)
extra_features = set(all_features) - set(X.columns)

print("Missing features:", missing_features)
print("Extra features:", extra_features)
# Out:
# Total features defined: 36
# Actual features: 36
# Missing features: set()
# Extra features: set()

# %%
all_features = categorical_features + numerical_features + binary_features

print("Total features defined:", len(all_features))
print("Actual features:", X.shape[1])

missing_features = set(X.columns) - set(all_features)
extra_features = set(all_features) - set(X.columns)

print("Missing features:", missing_features)
print("Extra features:", extra_features)
# Out:
# Total features defined: 36
# Actual features: 36
# Missing features: set()
# Extra features: set()

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
preprocessor = ColumnTransformer(
    transformers=[
        (
            "categorical",
            OneHotEncoder(handle_unknown="ignore"),
            categorical_features
        ),
        (
            "numerical",
            StandardScaler(),
            numerical_features
        ),
        (
            "binary",
            "passthrough",
            binary_features
        )
    ]
)

# %%
OneHotEncoder(handle_unknown="ignore")
# Out:
# OneHotEncoder(handle_unknown='ignore')

# %%
StandardScaler()
# Out:
# StandardScaler()

# %%
X_train_processed = preprocessor.fit_transform(X_train)

# %%
X_test_processed = preprocessor.transform(X_test)

# %%
transform()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 transform()
#
# NameError: name 'transform' is not defined

# %%
print("Original X_train shape:", X_train.shape)
print("Processed X_train shape:", X_train_processed.shape)

print("Original X_test shape:", X_test.shape)
print("Processed X_test shape:", X_test_processed.shape)
# Out:
# Original X_train shape: (3539, 36)
# Processed X_train shape: (3539, 244)
# Original X_test shape: (885, 36)
# Processed X_test shape: (885, 244)

# %%
print(type(X_train_processed))
# Out:
# <class 'scipy.sparse._csr.csr_matrix'>

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
preprocessor = ColumnTransformer(
    transformers=[
        (
            "categorical",
            OneHotEncoder(handle_unknown="ignore"),
            categorical_features
        ),
        (
            "numerical",
            StandardScaler(),
            numerical_features
        ),
        (
            "binary",
            "passthrough",
            binary_features
        )
    ]
)

# %%
X_train_processed = preprocessor.fit_transform(X_train)

# %%
X_test_processed = preprocessor.transform(X_test)

print("Original X_train:", X_train.shape)
print("Processed X_train:", X_train_processed.shape)

print("Original X_test:", X_test.shape)
print("Processed X_test:", X_test_processed.shape)

print("Processed data type:", type(X_train_processed))
# Out:
# Original X_train: (3539, 36)
# Processed X_train: (3539, 244)
# Original X_test: (885, 36)
# Processed X_test: (885, 244)
# Processed data type: <class 'scipy.sparse._csr.csr_matrix'>

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_model = LogisticRegression(
    max_iter=2000,
    random_state=42
)

# %%
logistic_model.fit(X_train_processed, y_train)
# Out:
# LogisticRegression(max_iter=2000, random_state=42)

# %%
y_pred = logistic_model.predict(X_test_processed)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 0.7684
# Accuracy: 76.84%

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      Dropout       0.79      0.75      0.77       284
#     Enrolled       0.55      0.40      0.46       159
#     Graduate       0.81      0.91      0.86       442
#
#     accuracy                           0.77       885
#    macro avg       0.72      0.69      0.70       885
# weighted avg       0.76      0.77      0.76       885

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=logistic_model.classes_
)

disp.plot()

plt.title("Logistic Regression - Confusion Matrix")
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_model = LogisticRegression(
    max_iter=2000,
    random_state=42
)

# %%
logistic_model.fit(X_train_processed, y_train)
# Out:
# LogisticRegression(max_iter=2000, random_state=42)

# %%
y_pred = logistic_model.predict(X_test_processed)

print("Predictions generated successfully!")
print("Number of predictions:", len(y_pred))
# Out:
# Predictions generated successfully!
# Number of predictions: 885

# %%
comparison = pd.DataFrame({
    "Actual": y_test.values,
    "Predicted": y_pred
})

comparison.head(20)
# Out:
#       Actual Predicted
# 0   Graduate  Graduate
# 1   Graduate  Graduate
# 2   Enrolled   Dropout
# 3   Graduate  Graduate
# 4   Graduate  Graduate
# 5   Graduate   Dropout
# 6   Graduate  Graduate
# 7   Graduate  Graduate
# 8   Graduate  Graduate
# 9   Graduate  Graduate
# 10  Graduate  Graduate
# 11  Enrolled  Enrolled
# 12   Dropout   Dropout
# 13   Dropout   Dropout
# 14  Enrolled  Enrolled
# 15  Enrolled  Enrolled
# 16  Graduate  Graduate
# 17  Enrolled   Dropout
# 18   Dropout   Dropout
# 19   Dropout   Dropout

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 0.7684
# Accuracy: 76.84%

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      Dropout       0.79      0.75      0.77       284
#     Enrolled       0.55      0.40      0.46       159
#     Graduate       0.81      0.91      0.86       442
#
#     accuracy                           0.77       885
#    macro avg       0.72      0.69      0.70       885
# weighted avg       0.76      0.77      0.76       885

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=logistic_model.classes_
)

disp.plot()

plt.title("Logistic Regression - Confusion Matrix")
plt.show()

# %%
y_pred = logistic_model.predict(X_test_processed)

print("Number of predictions:", len(y_pred))
# Out:
# Number of predictions: 885

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 0.7684
# Accuracy: 76.84%

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      Dropout       0.79      0.75      0.77       284
#     Enrolled       0.55      0.40      0.46       159
#     Graduate       0.81      0.91      0.86       442
#
#     accuracy                           0.77       885
#    macro avg       0.72      0.69      0.70       885
# weighted avg       0.76      0.77      0.76       885

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(cm)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=logistic_model.classes_
)

disp.plot()

plt.title("Logistic Regression - Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
# [[214  30  40]
#  [ 39  63  57]
#  [ 18  21 403]]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(cm)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=logistic_model.classes_
)

disp.plot()

plt.title("Logistic Regression - Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
# [[214  30  40]
#  [ 39  63  57]
#  [ 18  21 403]]

# %%
from sklearn.tree import DecisionTreeClassifier

decision_tree = DecisionTreeClassifier(
    max_depth=8,
    random_state=42
)

# %%
decision_tree.fit(X_train_processed, y_train)
# Out:
# DecisionTreeClassifier(max_depth=8, random_state=42)

# %%
y_pred_tree = decision_tree.predict(X_test_processed)

print("Number of predictions:", len(y_pred_tree))
# Out:
# Number of predictions: 885

# %%
from sklearn.metrics import accuracy_score

tree_accuracy = accuracy_score(y_test, y_pred_tree)

print(f"Decision Tree Accuracy: {tree_accuracy:.4f}")
print(f"Decision Tree Accuracy: {tree_accuracy * 100:.2f}%")
# Out:
# Decision Tree Accuracy: 0.7243
# Decision Tree Accuracy: 72.43%

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_tree))
# Out:
#               precision    recall  f1-score   support
#
#      Dropout       0.78      0.67      0.72       284
#     Enrolled       0.43      0.45      0.44       159
#     Graduate       0.80      0.86      0.83       442
#
#     accuracy                           0.72       885
#    macro avg       0.67      0.66      0.66       885
# weighted avg       0.73      0.72      0.72       885

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm_tree = confusion_matrix(y_test, y_pred_tree)

print("Decision Tree Confusion Matrix:")
print(cm_tree)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm_tree,
    display_labels=decision_tree.classes_
)

disp.plot()

plt.title("Decision Tree - Confusion Matrix")
plt.show()
# Out:
# Decision Tree Confusion Matrix:
# [[190  52  42]
#  [ 36  72  51]
#  [ 19  44 379]]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random_forest = RandomForestClassifier(
    n_estimators=300,
    random_state=42,
    n_jobs=-1
)

# %%
random_forest.fit(X_train_processed, y_train)
# Out:
# RandomForestClassifier(n_estimators=300, n_jobs=-1, random_state=42)

# %%
y_pred_rf = random_forest.predict(X_test_processed)

print("Number of predictions:", len(y_pred_rf))
# Out:
# Number of predictions: 885

# %%
rf_accuracy = accuracy_score(y_test, y_pred_rf)

print(f"Random Forest Accuracy: {rf_accuracy:.4f}")
print(f"Random Forest Accuracy: {rf_accuracy * 100:.2f}%")

print("\nClassification Report:")
print(classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.7650
# Random Forest Accuracy: 76.50%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Dropout       0.79      0.76      0.77       284
#     Enrolled       0.58      0.26      0.36       159
#     Graduate       0.78      0.95      0.85       442
#
#     accuracy                           0.76       885
#    macro avg       0.72      0.66      0.66       885
# weighted avg       0.75      0.76      0.74       885

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm_rf = confusion_matrix(y_test, y_pred_rf)

print("Random Forest Confusion Matrix:")
print(cm_rf)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm_rf,
    display_labels=random_forest.classes_
)

disp.plot()

plt.title("Random Forest - Confusion Matrix")
plt.show()
# Out:
# Random Forest Confusion Matrix:
# [[215  20  49]
#  [ 45  42  72]
#  [ 12  10 420]]

# %%
feature_names = preprocessor.get_feature_names_out()

print("Number of processed feature names:", len(feature_names))
# Out:
# Number of processed feature names: 244

# %%
importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Importance": random_forest.feature_importances_
})

importance_df = importance_df.sort_values(
    by="Importance",
    ascending=False
)

importance_df.head(20)
# Out:
#                                                Feature  Importance
# 231     numerical__Curricular units 2nd sem (approved)    0.110966
# 225     numerical__Curricular units 1st sem (approved)    0.080632
# 232        numerical__Curricular units 2nd sem (grade)    0.079816
# 226        numerical__Curricular units 1st sem (grade)    0.058838
# 230  numerical__Curricular units 2nd sem (evaluations)    0.040314
# 220                         numerical__Admission grade    0.035083
# 221                       numerical__Age at enrollment    0.033710
# 224  numerical__Curricular units 1st sem (evaluations)    0.033338
# 219          numerical__Previous qualification (grade)    0.031966
# 240                    binary__Tuition fees up to date    0.030872
# 234                       numerical__Unemployment rate    0.020775
# 236                                     numerical__GDP    0.020633
# 235                          numerical__Inflation rate    0.018821
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gradient_boosting = GradientBoostingClassifier(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=3,
    random_state=42
)

# %%
gradient_boosting.fit(X_train_processed, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.05, n_estimators=200,
#                            random_state=42)

# %%
y_pred_gb = gradient_boosting.predict(X_test_processed)

gb_accuracy = accuracy_score(y_test, y_pred_gb)

print(f"Gradient Boosting Accuracy: {gb_accuracy:.4f}")
print(f"Gradient Boosting Accuracy: {gb_accuracy * 100:.2f}%")

print("\nClassification Report:")
print(classification_report(y_test, y_pred_gb))
# Out:
# Gradient Boosting Accuracy: 0.7559
# Gradient Boosting Accuracy: 75.59%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Dropout       0.79      0.75      0.77       284
#     Enrolled       0.51      0.34      0.41       159
#     Graduate       0.79      0.91      0.85       442
#
#     accuracy                           0.76       885
#    macro avg       0.70      0.67      0.67       885
# weighted avg       0.74      0.76      0.74       885

# %%
balanced_logistic = LogisticRegression(
    max_iter=2000,
    class_weight="balanced",
    random_state=42
)

# %%
balanced_logistic.fit(
    X_train_processed,
    y_train
)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=2000, random_state=42)

# %%
y_pred_balanced = balanced_logistic.predict(
    X_test_processed
)

# %%
balanced_accuracy = accuracy_score(
    y_test,
    y_pred_balanced
)

print(f"Balanced Logistic Regression Accuracy: {balanced_accuracy:.4f}")
print(f"Balanced Logistic Regression Accuracy: {balanced_accuracy * 100:.2f}%")

print("\nClassification Report:")
print(classification_report(
    y_test,
    y_pred_balanced
))
# Out:
# Balanced Logistic Regression Accuracy: 0.7254
# Balanced Logistic Regression Accuracy: 72.54%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Dropout       0.82      0.68      0.75       284
#     Enrolled       0.41      0.64      0.50       159
#     Graduate       0.86      0.78      0.82       442
#
#     accuracy                           0.73       885
#    macro avg       0.70      0.70      0.69       885
# weighted avg       0.77      0.73      0.74       885

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_scores = cross_val_score(
    logistic_model,
    X_train_processed,
    y_train,
    cv=5,
    scoring="accuracy",
    n_jobs=-1
)

print("Cross-validation scores:")
print(cv_scores)

print("\nMean CV Accuracy:", cv_scores.mean())
print("Standard Deviation:", cv_scores.std())
# Out:
# Cross-validation scores:
# [0.75564972 0.79237288 0.78389831 0.77966102 0.7864215 ]
#
# Mean CV Accuracy: 0.7796006840393483
# Standard Deviation: 0.01266313175496124

# %%
cv_f1_scores = cross_val_score(
    logistic_model,
    X_train_processed,
    y_train,
    cv=5,
    scoring="f1_macro",
    n_jobs=-1
)

print("Cross-validation Macro F1 scores:")
print(cv_f1_scores)

print("\nMean CV Macro F1:", cv_f1_scores.mean())
print("Standard Deviation:", cv_f1_scores.std())
# Out:
# Cross-validation Macro F1 scores:
# [0.67754085 0.72209334 0.70770408 0.71461381 0.72250781]
#
# Mean CV Macro F1: 0.7088919786127464
# Standard Deviation: 0.016593435166625245

# %%
from sklearn.pipeline import Pipeline

final_model = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", LogisticRegression(
        max_iter=2000,
        random_state=42
    ))
])

# %%
final_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Marital status',
#                                                    'Application mode',
#                                                    'Application order',
#                                                    'Course',
#                                                    'Daytime/evening attendance',
#                                                    'Previous qualification',
#                                                    'Nacionality',
#                                                    "Mother's qualification",
#                                                    "Father's qualification",
#                                                    "Mother's occupation",
# ...

# %%
final_pred = final_model.predict(X_test)

final_accuracy = accuracy_score(y_test, final_pred)

print(f"Final Model Accuracy: {final_accuracy:.4f}")
print(f"Final Model Accuracy: {final_accuracy * 100:.2f}%")

print("\nFinal Classification Report:")
print(classification_report(y_test, final_pred))
# Out:
# Final Model Accuracy: 0.7684
# Final Model Accuracy: 76.84%
#
# Final Classification Report:
#               precision    recall  f1-score   support
#
#      Dropout       0.79      0.75      0.77       284
#     Enrolled       0.55      0.40      0.46       159
#     Graduate       0.81      0.91      0.86       442
#
#     accuracy                           0.77       885
#    macro avg       0.72      0.69      0.70       885
# weighted avg       0.76      0.77      0.76       885

# %%
from pathlib import Path
import joblib

# Create models folder
model_path = Path("../models/edupredict_model.joblib")
model_path.parent.mkdir(parents=True, exist_ok=True)

# Save complete pipeline
joblib.dump(final_model, model_path)

print("Model saved successfully!")
print("Saved at:", model_path.resolve())
# Out:
# Model saved successfully!
# Saved at: D:\Sunny Project\EduPredict\models\edupredict_model.joblib

# %%
import joblib

# Load saved model
loaded_model = joblib.load("../models/edupredict_model.joblib")

# Make predictions using loaded model
loaded_predictions = loaded_model.predict(X_test)

# Check whether predictions match
same_predictions = (loaded_predictions == final_pred).all()

print("Model loaded successfully!")
print("Predictions match:", same_predictions)
# Out:
# Model loaded successfully!
# Predictions match: True

# %%
def predict_student(student_data):
    # Convert dictionary into DataFrame
    input_df = pd.DataFrame([student_data])

    # Prediction
    prediction = loaded_model.predict(input_df)[0]

    # Prediction probabilities
    probabilities = loaded_model.predict_proba(input_df)[0]

    # Map probabilities with class names
    probability_dict = dict(
        zip(loaded_model.classes_, probabilities)
    )

    return prediction, probability_dict

# %%
sample_student = {
    "Marital status": 1,
    "Application mode": 17,
    "Application order": 1,
    "Course": 9238,
    "Daytime/evening attendance": 1,
    "Previous qualification": 1,
    "Previous qualification (grade)": 125.0,
    "Nacionality": 1,
    "Mother's qualification": 13,
    "Father's qualification": 10,
    "Mother's occupation": 6,
    "Father's occupation": 8,
    "Admission grade": 130.0,
    "Displaced": 0,
    "Educational special needs": 0,
    "Debtor": 0,
    "Tuition fees up to date": 1,
    "Gender": 1,
    "Scholarship holder": 0,
    "Age at enrollment": 19,
    "International": 0,

    "Curricular units 1st sem (credited)": 0,
    "Curricular units 1st sem (enrolled)": 6,
    "Curricular units 1st sem (evaluations)": 6,
    "Curricular units 1st sem (approved)": 5,
    "Curricular units 1st sem (grade)": 13.5,
    "Curricular units 1st sem (without evaluations)": 0,

    "Curricular units 2nd sem (credited)": 0,
    "Curricular units 2nd sem (enrolled)": 6,
    "Curricular units 2nd sem (evaluations)": 6,
    "Curricular units 2nd sem (approved)": 5,
    "Curricular units 2nd sem (grade)": 13.0,
    "Curricular units 2nd sem (without evaluations)": 0,

    "Unemployment rate": 10.8,
    "Inflation rate": 1.4,
    "GDP": 1.74
}

prediction, probabilities = predict_student(sample_student)

print("Predicted Outcome:", prediction)
print("\nPrediction Probabilities:")

for class_name, probability in probabilities.items():
    print(f"{class_name}: {probability * 100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 43
#      39     "Inflation rate": 1.4,
#      40     "GDP": 1.74
#      41 }
#      42
# ---> 43 prediction, probabilities = predict_student(sample_student)
#      44
#      45 print("Predicted Outcome:", prediction)
#      46 print("\nPrediction Probabilities:")
#
# Cell In[1], line 3, in predict_student(student_data)
#       1 def predict_student(student_data):
#       2     # Convert dictionary into DataFrame
# ----> 3     input_df = pd.DataFrame([student_data])
#       4
#       5     # Prediction
#       6     prediction = loaded_model.predict(input_df)[0]
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
prediction, probabilities = predict_student(sample_student)

print("Predicted Outcome:", prediction)
print("\nPrediction Probabilities:")

for class_name, probability in probabilities.items():
    print(f"{class_name}: {probability * 100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 prediction, probabilities = predict_student(sample_student)
#       2
#       3 print("Predicted Outcome:", prediction)
#       4 print("\nPrediction Probabilities:")
#
# Cell In[1], line 6, in predict_student(student_data)
#       2     # Convert dictionary into DataFrame
#       3     input_df = pd.DataFrame([student_data])
#       4
#       5     # Prediction
# ----> 6     prediction = loaded_model.predict(input_df)[0]
#       7
#       8     # Prediction probabilities
#       9     probabilities = loaded_model.predict_proba(input_df)[0]
#
# NameError: name 'loaded_model' is not defined

# %%
import joblib
import pandas as pd

loaded_model = joblib.load("../models/edupredict_model.joblib")

print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %%
def predict_student(student_data):
    input_df = pd.DataFrame([student_data])

    prediction = loaded_model.predict(input_df)[0]

    probabilities = loaded_model.predict_proba(input_df)[0]

    probability_dict = dict(
        zip(loaded_model.classes_, probabilities)
    )

    return prediction, probability_dict

print("Prediction function ready!")
# Out:
# Prediction function ready!

# %%
prediction, probabilities = predict_student(sample_student)

print("Predicted Outcome:", prediction)
print("\nPrediction Probabilities:")

for class_name, probability in probabilities.items():
    print(f"{class_name}: {probability * 100:.2f}%")
# Out:
# Predicted Outcome: Graduate
#
# Prediction Probabilities:
# Dropout: 5.89%
# Enrolled: 4.33%
# Graduate: 89.78%
